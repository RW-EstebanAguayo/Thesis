# %%
# pip install opyf

# %%
import opyf
analyzer = opyf.frameSequenceAnalyzer("C:/Users/estal/OneDrive - ROCKWOOL Group/Documents/GD/Thesis/04_Code/src/data/raw/PIV_dataset/DNS_test")
# Out:
# Dimensions :
#  	 Width : 256 Height : 256
# Regio Of Interest :
#  	 [0, 0, 256, 256]
#
# Good Features To Track Parameters:
# 	-  maxCorners : 40000
# 	-  qualityLevel : 0.005
# 	-  minDistance : 5
# 	-  blockSize : 16
#
# Optical Flow Parameters:
# 	-  winSize : (16, 16)
# 	-  maxLevel : 3
# 	-  criteria : (3, 50, 0.03)
#
# Filters Params:
# 	-  RadiusF : 30
# 	-  minNperRadius : 0
# 	-  maxDevInRadius : inf
# 	-  wayBackGoodFlag : inf
# 	-  CLAHE : False
# 	-  range_Vx : [-inf, inf]
# 	-  range_Vy : [-inf, inf]
# 	-  clplim : 3
# 	-  gridSize : (20, 20)
#
# Interpolation Parameters:
# 	-  Radius : 30
# 	-  Sharpness : 8
# 	-  kernel : Gaussian
#
# [The following image processing plan has been set]
# --> detect Good Features to Track on image [DNS_turbulence_00001_img1.tif]
# --> diplacements measurement between images [DNS_turbulence_00001_img1.tif] and [DNS_turbulence_00001_img2.tif]
# number of frames : 2

# %%
analyzer.extractGoodFeaturesAndDisplacements()
# Out:
# -------------- [Step 1 / 1] --------------
# ------- From frame [DNS_turbulence_00001_img1.tif] to frame [DNS_turbulence_00001_img2.tif] -------
# Number of Good Feature To Track = 935
# Displacement max = 2.662056 px/deltaT
